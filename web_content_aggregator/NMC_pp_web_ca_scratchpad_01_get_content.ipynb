# %% [markdown]
# # Get_content scratchpad
# ---
# **Goal:** get content for several content sources and figure out a general pattern for the process.

# %%
import requests
import xml.etree.ElementTree as ET
import my_config as cfg

# %%
HEADERS = cfg.HEADERS

# %% [markdown]
# ## 1. NCBI <small>(National Center for Biotechnology Information)</small>
# - request type: RSS
# - response type: XML

# %%
url = 'https://ncbiinsights.ncbi.nlm.nih.gov/'
url_rss = 'https://ncbiinsights.ncbi.nlm.nih.gov/feed/'

# %%
r = requests.get(url, headers = HEADERS)
print(r.status_code)
r.content
# Out:
# 200
# ...

# %%
rr = requests.get(url_rss, headers = HEADERS)
print(rr.status_code)
rr.content
# Out:
# 200
# ...

# %%
import pprint

# %%
pprint.pprint(rr.content)
# Out:
# (b'<?xml version="1.0" encoding="UTF-8"?><rss version="2.0"\n\txmlns:content='
#  b'"http://purl.org/rss/1.0/modules/content/"\n\txmlns:wfw="http://wellformed'
#  b'web.org/CommentAPI/"\n\txmlns:dc="http://purl.org/dc/elements/1.1/"\n\txmlns'
#  b':atom="http://www.w3.org/2005/Atom"\n\txmlns:sy="http://purl.org/rss/1.0/m'
#  b'odules/syndication/"\n\txmlns:slash="http://purl.org/rss/1.0/modules/slash'
#  b'/"\n\t\n\txmlns:georss="http://www.georss.org/georss"\n\txmlns:geo="http:/'
#  b'/www.w3.org/2003/01/geo/wgs84_pos#"\n\t>\n\n<channel>\n\t<title>NCBI Insig'
#  b'hts</title>\n\t<atom:link href="https://ncbiinsights.ncbi.nlm.nih.gov/feed'
#  b'/" rel="self" type="application/rss+xml" />\n\t<link>https://ncbiinsights.'
#  b'ncbi.nlm.nih.gov</link>\n\t<description>NCBI Logo</description>\n\t<lastBuil'
#  b'dDate>Wed, 17 Mar 2021 18:18:54 +0000</lastBuildDate>\n\t<language>en-US</'
#  b'language>\n\t<sy:updatePeriod>\n\thourly\t</sy:updatePeriod>\n\t<sy:updateF'
# ...
